# %% [markdown]
# # Linear Algebra

# %%
#imports - one single time for the entire notebook
import torch
import math

# %% [markdown]
# ## Calculate Eigenvalues of a Matrix

# %%
def calculate_eigenvalues(matrix: torch.Tensor) -> torch.Tensor:
    """
    Compute eigenvalues of a 2x2 matrix using PyTorch.
    Input: 2x2 tensor; Output: 1-D tensor with the two eigenvalues in descending order (highest to lowest).
    """
    # Your implementation here
    a = 1
    b = -(matrix[0,0]+matrix[1,1])
    c = matrix[0,0]*matrix[1,1] - matrix[1,0]*matrix[0,1]
    delta = b**2-4*a*c
    return torch.tensor([(-b+math.sqrt(delta))/2*a, (-b-math.sqrt(delta))/2*a])

# %%
calculate_eigenvalues(torch.tensor([[1.0,2.0],[2.2,3.4]]))
# Out:
# tensor([ 4.6166, -0.2166])

# %% [markdown]
# ## Matrix Transformation

# %%
def transform_matrix(A, T, S) -> torch.Tensor:
    """
    Perform the change-of-basis transform Tâ»Â¹ A S and round to 3 decimals using PyTorch.
    Inputs A, T, S can be Python lists, NumPy arrays, or torch Tensors.
    Returns a ?? tensor or tensor(-1.) if T or S is singular.
    """
    A_t = torch.as_tensor(A, dtype=torch.float)
    T_t = torch.as_tensor(T, dtype=torch.float)
    S_t = torch.as_tensor(S, dtype=torch.float)
    # Your implementation here
    pass
