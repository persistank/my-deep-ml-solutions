# %% [markdown]
# # Reinforcement learning

# %%
#imports - one single time for the entire notebook
import torch
import math
from typing import Dict, List, Tuple

# %% [markdown]
# ## Implement the SARSA Algorithm on policy

# %%
def sarsa_update(transitions: Dict[Tuple[str, str], Tuple[float, str]], 
                 initial_states: List[str], 
                 alpha: float, 
                 gamma: float, 
                 max_steps: int) -> Tuple[torch.Tensor, Dict[str, int], Dict[str, int]]:
    """
    Perform SARSA updates on the given environment transitions using PyTorch.
    
    Args:
        transitions: mapping (state, action) -> (reward, next_state)
        initial_states: list of starting states to simulate episodes from
        alpha: learning rate
        gamma: discount factor
        max_steps: maximum steps allowed per episode
        
    Returns:
        Tuple of (Q-table tensor of shape [num_states, num_actions], 
                  state_to_idx mapping, action_to_idx mapping)
    """
    def greedy():
        pass
